# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
plt.figure()

# define n
n = [10,100,1000,10000]
# generate random variables
i = 0
#Z = []
for n_ind in n:
    Z = np.random.randn(n_ind)
    plt.step(sorted(Z), np.arange(1,n_ind+1)/float(n_ind))

# %%
k = [1,8,64,512]
# generate n of Y(k) random variables 
n = 10000
for k_ind in k:
    Z = np.sum(np.sign(np.random.randn(n, k_ind))*np.sqrt(1./k_ind), axis=1)
    plt.step(sorted(Z), np.arange(1,n+1)/float(n))

# %%
np.empty
# Out:
# <function numpy.core.multiarray.empty>

# %%
    Z = np.random.randn(n_ind)

# %%
Z
# Out:
# array([-1.44466766,  0.17529561, -0.03703157, -0.19565077, -0.2354363 ,
#         0.57320276,  0.26324002, -0.03429831,  0.07830262,  0.52871685])
